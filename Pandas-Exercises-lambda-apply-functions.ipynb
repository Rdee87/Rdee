# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as nm
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
import numpy as nm
import pandas as pd
df1=pd.read_csv('C:/Users/VAIBHAV RUSTAGI/Downloads/student-mat.csv')
df2=pd.read_csv('C:/Users/VAIBHAV RUSTAGI/Downloads/student-por.csv')
df1.head()
df2.head()
display(pd.merge(df1, df2,   how='outer', validate="one_to_many"))
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# 5        GP   M   16       U     LE3       T     4     3  services     other
# 6        GP   M   16       U     LE3       T     2     2     other     other
# 7        GP   F   17       U     GT3       A     4     4     other   teacher
# 8        GP   M   15       U     LE3       A     3     2  services     other
# 9        GP   M   15       U     GT3       T     3     4     other     other
# 10       GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.merge(df1, df2,   how='outer', validate="one_to_many")

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df3 = df.loc[: , "school":"guardian"]
df3.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
capitalStr = lambda a: a.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df3['Mjob']=df3['Mjob'].apply(capitalStr)
df3['Fjob']=df3['Fjob'].apply(capitalStr)
df3['Mjob'].head()
df3['Fjob'].head()
# Out:
# 0     Teacher
# 1       Other
# 2       Other
# 3    Services
# 4       Other
# Name: Fjob, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df3.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   F   19       R     GT3       T     2     3  Services     Other
# 1040     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 1041     MS   F   18       U     GT3       T     1     1     Other     Other
# 1042     MS   M   17       U     LE3       T     3     1  Services  Services
# 1043     MS   M   18       R     LE3       T     3     2  Services     Other
#
#       reason guardian
# 1039  course   mother
# 1040  course   mother
# 1041  course   mother
# 1042  course   mother
# 1043  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df3['Mjob']=df3['Mjob'].apply(capitalStr)
df3['Fjob']=df3['Fjob'].apply(capitalStr)
df3['Mjob'].head()
df3['Fjob'].head()
# Out:
# 0     Teacher
# 1       Other
# 2       Other
# 3    Services
# 4       Other
# Name: Fjob, dtype: object

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x >=18:
         return True
    else: 
         return False
        

df3['legal_drinker']=df3['age'].apply(majority)
df3['legal_drinker'].head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: legal_drinker, dtype: bool

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
def multiply10(x):
    if type(x)==int:
        return x*10
    return x

df3.applymap(multiply10).head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  180       U     GT3       A    40    40  At_home   Teacher
# 1     GP   F  170       U     GT3       T    10    10  At_home     Other
# 2     GP   F  150       U     LE3       T    10    10  At_home     Other
# 3     GP   F  150       U     GT3       T    40    20   Health  Services
# 4     GP   F  160       U     GT3       T    30    30    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False
